# %%
def ile_czasu_czekania(pozycja_menu,godzina,minuty):
    spagetti = 17
    burger = 10
    salatka = 5
    menu = [ spagetti, burger, salatka ]
    minuta_jedzenia = minuty + menu[pozycja_menu]
    if minuta_jedzenia > 60:
        godzina = godzina + 1 
        minuta_jedzenia = minuta_jedzenia - 60


    print( f'moje jedzenie przyszło o {godzina}:{minuta_jedzenia} było bardzo smaczne:)')

o_ktorej_spagetti = ile_czasu_czekania(0,15,15)
o_ktorej_burger = ile_czasu_czekania(1,15,15)
o_ktorej_salatka = ile_czasu_czekania(2,15,56)
# Out:
# moje jedzenie przyszło o 15:32 było bardzo smaczne:)
# moje jedzenie przyszło o 15:25 było bardzo smaczne:)
# moje jedzenie przyszło o 16:1 było bardzo smaczne:)
