# %%
import random

odpowiedzi = [
    "Tak.",
    "Nie.",
    "Może.",
    "Raczej tak.",
    "Raczej nie.",
    "Chyba.",
    "Na pewno.",
    "Wątpię.",
    "Zdecydowanie.",
    "Nie licz na to.",
    "Brzmi sensownie.",
    "To możliwe.",
    "Mało prawdopodobne.",
    "Bardzo prawdopodobne.",
    "Jeszcze za wcześnie, by stwierdzić.",
    "Zapytaj później.",
    "Nie teraz.",
    "Spróbuj ponownie.",
    "Nie mam zdania.",
    "Trudno powiedzieć.",
    "Nie wiem.",
    "Wszystko wskazuje na tak.",
    "Wszystko wskazuje na nie.",
    "Los mówi: tak.",
    "Los mówi: nie.",
    "Zależy.",
    "To się okaże.",
    "Bez komentarza.",
    "Skup się i zapytaj ponownie.",
    "Lepiej tego nie sprawdzaj."
]
losowa = random.randint(0,len(odpowiedzi))
losowa_odpowiedz = odpowiedzi[losowa]

print(losowa_odpowiedz)
# Out:
# Wątpię.
