# %%
import random

odpowiedzi = [
    "Tak.",
    "Nie.",
    "Może.",
    "Raczej tak.",
    "Raczej nie.",
    "Chyba.",
    "Na pewno.",
    "Wątpię.",
    "Zdecydowanie.",
    "Nie licz na to.",
    "Brzmi sensownie.",
    "To możliwe.",
    "Mało prawdopodobne.",
    "Bardzo prawdopodobne.",
    "Jeszcze za wcześnie, by stwierdzić.",
    "Zapytaj później.",
    "Nie teraz.",
    "Spróbuj ponownie.",
    "Nie mam zdania.",
    "Trudno powiedzieć.",
    "Nie wiem.",
    "Wszystko wskazuje na tak.",
    "Wszystko wskazuje na nie.",
    "Los mówi: tak.",
    "Los mówi: nie.",
    "Zależy.",
    "To się okaże.",
    "Bez komentarza.",
    "Skup się i zapytaj ponownie.",
    "Lepiej tego nie sprawdzaj."
]
dlugosc = len(odpowiedzi)
losowa = random.randint(0,dlugosc)
losowa_odpowiedz = odpowiedzi[losowa]

print(losowa_odpowiedz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 35
#       1 import random
#       3 odpowiedzi = [
#       4     "Tak.",
#       5     "Nie.",
#    (...)     33     "Lepiej tego nie sprawdzaj."
#      34 ]
# ---> 35 losowa = random.randint((odpowiedzi))
#      36 losowa_odpowiedz = odpowiedzi[losow0,lena]
#      38 print(losowa_odpowiedz)
#
# TypeError: Random.randint() missing 1 required positional argument: 'b'
