# %% [markdown]
# 🍬 Zadanie: Maszyna do Dzielenia Cukierków
#
# Hania ma N cukierków i chce podzielić je po równo między 3 najlepsze koleżanki.
# Maszyna do dzielenia działa tylko wtedy, gdy:
#
# Każda koleżanka dostaje taką samą, całkowitą liczbę cukierków.
#
# Żadnego cukierka nie wolno łamać ani kroić.
#
# Zadanie
#
# Dla danej liczby N (liczba cukierków) ustal:
#
# Ile cukierków dostanie każda koleżanka,
#
# Ile cukierków zostanie niewykorzystanych.
#
# Przykład
#
# Jeśli N = 14:
#
# Każda koleżanka dostaje 4 cukierki
#
# Zostają 2 cukierki

# %%
def dziel_cukierki(ile_cukierkow):
    jedna_kolezanka = 0
    reszta_cukierkow = 0
    reszta_cukierkow = ile_cukierkow % 3
    jedna_kolezanka = ile_cukierkow - reszta_cukierkow
    
    return (reszta_cukierkow, jedna_kolezanka)

# %%
cukierki = 14
reszta, jedna_kolezanka = dziel_cukierki(cukierki)
# Out:
# 1
