# %%
def ile_razy_odbicie(srednica_pilki,wysokosc):
    odbicie_pilki = 0
    while wysokosc > srednica_pilki:
        wysokosc = wysokosc/2
        odbicie_pilki = odbicie_pilki + 1
    return odbicie_pilki

# %%
odbicia_pilki = ile_razy_odbicie(4,20)

print(odbicia_pilki)
# Out:
# 3
